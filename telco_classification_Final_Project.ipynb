# %% [markdown]
# # $Telco$ $Churn$

# %% [markdown]
# # **Goals:**

# %% [markdown]
# * Discover the drivers of customer churn within the Telco company.
#
# * Use drivers to built models that can predict if a Telco customer will churn.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np

import wrangle as w
import explore as e
import model as m
randomseed = 123

import warnings
warnings.filterwarnings("ignore")

pd.set_option('display.max_columns', None)

# %% [markdown]
# # Acquire:

# %% [markdown]
# * Data acquire from Codeup Database 10/27/22
#
# * It contained  7043 rows and 24 columns before cleaning
#
# * Each row represents a Telco customers
#
# * Each column represents a feature related to the customer.

# %%
# acquire telco data 
df = w.get_telco_data()

# %% [markdown]
# # Prepare:

# %% [markdown]
# prepare actions:

# %% [markdown]
# * Removed columns that contain unuseful information.
# * Removed columns that contain redundant information.
# * Removed 11 observations with whitespace in total charges column.
# * Checked columns were the appropriate data type.
#     * Total charges was converted to appropriate numeric data type.
# * Null values where not found
# * Outliers have not been removed
# * Encoded categorical variables
# * Split data into train, validate and test
#     * Approximately: train 56%, validate 24%, test 20%
#     * Stratifying on 'churn'

# %% [markdown]
# ###                                                             Data Dictionary

# %% [markdown]
# | Feature | Definition |
# | --- | --- |
# | Gender | Whether a customer is male or female |
# | Senior Citizen | Whether a customer is Senior Citizen (1) or not (0) |
# | Partner | Whether the customer has a partner or not |
# | Dependents | Whether the customer has dependents or not |
# | Tenure | Number of months the customer has stayed with the company |
# | PhoneService | Whether the customer has a phone service or not |
# | MultipleLines | Whether the customer has multiple lines or not (Yes, No, No phone service)|
# | InternetService | Customer’s internet service provider (DSL, Fiber optic, No internet srvice)|
# | OnlineSecurity | Whether the customer has online security or not (Yes, No, No internet service) |
# | Additional Features | Encoded and values for categorical data and scaled versions continuous data|

# %%
# cleaning data
df = w.prep_telco(df)

# split data: train, validate and test
train, validate, test = w.split_telco_data(df)

# %% [markdown]
# # Looking at the data

# %%
train.head(10)
# Out:
#      customer_id  gender  senior_citizen partner dependents  tenure  \
# 5919  8331-ZXFOE  Female               0      No         No      58
# 1915  2790-XUYMV    Male               0      No        Yes      71
# 5054  7107-UBYKY  Female               0     Yes        Yes      35
# 2355  3373-YZZYM    Male               0     Yes        Yes       1
# 6279  8883-GRDWQ    Male               1      No         No      20
# 6992  9921-ZVRHG  Female               0      No         No      14
# 3614  5129-HHMZC  Female               0     Yes         No      43
# 4352  6135-OZQVA  Female               0      No         No       7
# 6845  9722-UJOJR    Male               0     Yes        Yes      29
# 3782  5320-BRKGK  Female               0     Yes        Yes      58
#
#      phone_service multiple_lines      online_security        online_backup  \
# 5919           Yes            Yes                  Yes                  Yes
# 1915           Yes            Yes                  Yes                  Yes
# 5054           Yes            Yes  No internet service  No internet service
# 2355           Yes             No  No internet service  No internet service
# 6279           Yes             No                  Yes                   No
# 6992           Yes            Yes                   No                   No
# 3614           Yes            Yes                  Yes                  Yes
# 4352           Yes            Yes                  Yes                   No
# 6845           Yes             No                   No                   No
# 3782           Yes            Yes                  Yes                   No
#
#         device_protection         tech_support         streaming_tv  \
# 5919                  Yes                  Yes                   No
# 1915                   No                   No                   No
# 5054  No internet service  No internet service  No internet service
# 2355  No internet service  No internet service  No internet service
# 6279                   No                  Yes                   No
# 6992                  Yes                   No                   No
# 3614                   No                  Yes                  Yes
# 4352                   No                   No                   No
# 6845                   No                   No                   No
# 3782                  Yes                  Yes                  Yes
#
#          streaming_movies paperless_billing  monthly_charges  total_charges  \
# 5919                   No               Yes            71.10        4299.20
# 1915                   No               Yes            85.45        6028.95
# 5054  No internet service               Yes            25.75         882.55
# 2355  No internet service                No            19.20          19.20
# 6279                   No                No            54.00        1055.90
# 6992                   No               Yes            80.45        1072.00
# 3614                  Yes                No            86.45        3574.50
# 4352                   No               Yes            53.65         404.35
# 6845                   No               Yes            70.75        1974.80
# 3782                   No                No            75.80        4415.75
#
#      churn   contract_type internet_service_type             payment_type  \
# 5919    No        One year                   DSL  Credit card (automatic)
# 1915    No        One year           Fiber optic  Credit card (automatic)
# 5054    No  Month-to-month                  None         Electronic check
# 2355    No  Month-to-month                  None             Mailed check
# 6279    No        One year                   DSL             Mailed check
# 6992   Yes  Month-to-month           Fiber optic         Electronic check
# 3614    No        Two year                   DSL  Credit card (automatic)
# 4352    No  Month-to-month                   DSL         Electronic check
# 6845   Yes  Month-to-month           Fiber optic         Electronic check
# 3782    No        Two year                   DSL             Mailed check
#
#       gender_Female  gender_Male  partner_No  partner_Yes  dependents_No  \
# 5919              1            0           1            0              1
# 1915              0            1           1            0              0
# 5054              1            0           0            1              0
# 2355              0            1           0            1              0
# 6279              0            1           1            0              1
# 6992              1            0           1            0              1
# 3614              1            0           0            1              1
# 4352              1            0           1            0              1
# 6845              0            1           0            1              0
# 3782              1            0           0            1              0
#
#       dependents_Yes  phone_service_No  phone_service_Yes  multiple_lines_No  \
# 5919               0                 0                  1                  0
# 1915               1                 0                  1                  0
# 5054               1                 0                  1                  0
# 2355               1                 0                  1                  1
# 6279               0                 0                  1                  1
# 6992               0                 0                  1                  0
# 3614               0                 0                  1                  0
# 4352               0                 0                  1                  0
# 6845               1                 0                  1                  1
# 3782               1                 0                  1                  0
#
#       multiple_lines_No phone service  multiple_lines_Yes  online_security_No  \
# 5919                                0                   1                   0
# 1915                                0                   1                   0
# 5054                                0                   1                   0
# 2355                                0                   0                   0
# 6279                                0                   0                   0
# 6992                                0                   1                   1
# 3614                                0                   1                   0
# 4352                                0                   1                   0
# 6845                                0                   0                   1
# 3782                                0                   1                   0
#
#       online_security_No internet service  online_security_Yes  \
# 5919                                    0                    1
# 1915                                    0                    1
# 5054                                    1                    0
# 2355                                    1                    0
# 6279                                    0                    1
# 6992                                    0                    0
# 3614                                    0                    1
# 4352                                    0                    1
# 6845                                    0                    0
# 3782                                    0                    1
#
#       online_backup_No  online_backup_No internet service  online_backup_Yes  \
# 5919                 0                                  0                  1
# 1915                 0                                  0                  1
# 5054                 0                                  1                  0
# 2355                 0                                  1                  0
# 6279                 1                                  0                  0
# 6992                 1                                  0                  0
# 3614                 0                                  0                  1
# 4352                 1                                  0                  0
# 6845                 1                                  0                  0
# 3782                 1                                  0                  0
#
#       device_protection_No  device_protection_No internet service  \
# 5919                     0                                      0
# 1915                     1                                      0
# 5054                     0                                      1
# 2355                     0                                      1
# 6279                     1                                      0
# 6992                     0                                      0
# 3614                     1                                      0
# 4352                     1                                      0
# 6845                     1                                      0
# 3782                     0                                      0
#
#       device_protection_Yes  tech_support_No  \
# 5919                      1                0
# 1915                      0                1
# 5054                      0                0
# 2355                      0                0
# 6279                      0                0
# 6992                      1                1
# 3614                      0                0
# 4352                      0                1
# 6845                      0                1
# 3782                      1                0
#
#       tech_support_No internet service  tech_support_Yes  streaming_tv_No  \
# 5919                                 0                 1                1
# 1915                                 0                 0                1
# 5054                                 1                 0                0
# 2355                                 1                 0                0
# 6279                                 0                 1                1
# 6992                                 0                 0                1
# 3614                                 0                 1                0
# 4352                                 0                 0                1
# 6845                                 0                 0                1
# 3782                                 0                 1                0
#
#       streaming_tv_No internet service  streaming_tv_Yes  streaming_movies_No  \
# 5919                                 0                 0                    1
# 1915                                 0                 0                    1
# 5054                                 1                 0                    0
# 2355                                 1                 0                    0
# 6279                                 0                 0                    1
# 6992                                 0                 0                    1
# 3614                                 0                 1                    0
# 4352                                 0                 0                    1
# 6845                                 0                 0                    1
# 3782                                 0                 1                    1
#
#       streaming_movies_No internet service  streaming_movies_Yes  \
# 5919                                     0                     0
# 1915                                     0                     0
# 5054                                     1                     0
# 2355                                     1                     0
# 6279                                     0                     0
# 6992                                     0                     0
# 3614                                     0                     1
# 4352                                     0                     0
# 6845                                     0                     0
# 3782                                     0                     0
#
#       paperless_billing_No  paperless_billing_Yes  \
# 5919                     0                      1
# 1915                     0                      1
# 5054                     0                      1
# 2355                     1                      0
# 6279                     1                      0
# 6992                     0                      1
# 3614                     1                      0
# 4352                     0                      1
# 6845                     0                      1
# 3782                     1                      0
#
#       contract_type_Month-to-month  contract_type_One year  \
# 5919                             0                       1
# 1915                             0                       1
# 5054                             1                       0
# 2355                             1                       0
# 6279                             0                       1
# 6992                             1                       0
# 3614                             0                       0
# 4352                             1                       0
# 6845                             1                       0
# 3782                             0                       0
#
#       contract_type_Two year  internet_service_type_DSL  \
# 5919                       0                          1
# 1915                       0                          0
# 5054                       0                          0
# 2355                       0                          0
# 6279                       0                          1
# 6992                       0                          0
# 3614                       1                          1
# 4352                       0                          1
# 6845                       0                          0
# 3782                       1                          1
#
#       internet_service_type_Fiber optic  internet_service_type_None  \
# 5919                                  0                           0
# 1915                                  1                           0
# 5054                                  0                           1
# 2355                                  0                           1
# 6279                                  0                           0
# 6992                                  1                           0
# 3614                                  0                           0
# 4352                                  0                           0
# 6845                                  1                           0
# 3782                                  0                           0
#
#       payment_type_Bank transfer (automatic)  \
# 5919                                       0
# 1915                                       0
# 5054                                       0
# 2355                                       0
# 6279                                       0
# 6992                                       0
# 3614                                       0
# 4352                                       0
# 6845                                       0
# 3782                                       0
#
#       payment_type_Credit card (automatic)  payment_type_Electronic check  \
# 5919                                     1                              0
# 1915                                     1                              0
# 5054                                     0                              1
# 2355                                     0                              0
# 6279                                     0                              0
# 6992                                     0                              1
# 3614                                     1                              0
# 4352                                     0                              1
# 6845                                     0                              1
# 3782                                     0                              0
#
#       payment_type_Mailed check
# 5919                          0
# 1915                          0
# 5054                          0
# 2355                          1
# 6279                          1
# 6992                          0
# 3614                          0
# 4352                          0
# 6845                          0
# 3782                          1

# %% [markdown]
# # Data Summary

# %%
train.describe()
# Out:
#        senior_citizen       tenure  monthly_charges  total_charges  \
# count     3937.000000  3937.000000      3937.000000    3937.000000
# mean         0.161290    32.775210        64.805131    2316.775641
# std          0.367845    24.709604        30.294804    2284.984394
# min          0.000000     1.000000        18.250000      18.850000
# 25%          0.000000     9.000000        34.700000     396.100000
# 50%          0.000000    30.000000        70.250000    1414.800000
# 75%          0.000000    56.000000        90.300000    3893.600000
# max          1.000000    72.000000       118.650000    8594.400000
#
#        gender_Female  gender_Male   partner_No  partner_Yes  dependents_No  \
# count    3937.000000  3937.000000  3937.000000  3937.000000    3937.000000
# mean        0.498095     0.501905     0.514859     0.485141       0.697231
# std         0.500060     0.500060     0.499843     0.499843       0.459514
# min         0.000000     0.000000     0.000000     0.000000       0.000000
# 25%         0.000000     0.000000     0.000000     0.000000       0.000000
# 50%         0.000000     1.000000     1.000000     0.000000       1.000000
# 75%         1.000000     1.000000     1.000000     1.000000       1.000000
# max         1.000000     1.000000     1.000000     1.000000       1.000000
#
#        dependents_Yes  phone_service_No  phone_service_Yes  multiple_lines_No  \
# count     3937.000000       3937.000000        3937.000000        3937.000000
# mean         0.302769          0.094742           0.905258           0.481331
# std          0.459514          0.292896           0.292896           0.499715
# min          0.000000          0.000000           0.000000           0.000000
# 25%          0.000000          0.000000           1.000000           0.000000
# 50%          0.000000          0.000000           1.000000           0.000000
# 75%          1.000000          0.000000           1.000000           1.000000
# max          1.000000          1.000000           1.000000           1.000000
#
#        multiple_lines_No phone service  multiple_lines_Yes  \
# count                      3937.000000         3937.000000
# mean                          0.094742            0.423927
# std                           0.292896            0.494242
# min                           0.000000            0.000000
# 25%                           0.000000            0.000000
# 50%                           0.000000            0.000000
# 75%                           0.000000            1.000000
# max                           1.000000            1.000000
#
#        online_security_No  online_security_No internet service  \
# count         3937.000000                          3937.000000
# mean             0.487173                             0.220218
# std              0.499899                             0.414447
# min              0.000000                             0.000000
# 25%              0.000000                             0.000000
# 50%              0.000000                             0.000000
# 75%              1.000000                             0.000000
# max              1.000000                             1.000000
#
#        online_security_Yes  online_backup_No  \
# count          3937.000000       3937.000000
# mean              0.292609          0.431039
# std               0.455018          0.495284
# min               0.000000          0.000000
# 25%               0.000000          0.000000
# 50%               0.000000          0.000000
# 75%               1.000000          1.000000
# max               1.000000          1.000000
#
#        online_backup_No internet service  online_backup_Yes  \
# count                        3937.000000        3937.000000
# mean                            0.220218           0.348743
# std                             0.414447           0.476633
# min                             0.000000           0.000000
# 25%                             0.000000           0.000000
# 50%                             0.000000           0.000000
# 75%                             0.000000           1.000000
# max                             1.000000           1.000000
#
#        device_protection_No  device_protection_No internet service  \
# count           3937.000000                            3937.000000
# mean               0.430023                               0.220218
# std                0.495142                               0.414447
# min                0.000000                               0.000000
# 25%                0.000000                               0.000000
# 50%                0.000000                               0.000000
# 75%                1.000000                               0.000000
# max                1.000000                               1.000000
#
#        device_protection_Yes  tech_support_No  \
# count            3937.000000      3937.000000
# mean                0.349759         0.490475
# std                 0.476954         0.499973
# min                 0.000000         0.000000
# 25%                 0.000000         0.000000
# 50%                 0.000000         0.000000
# 75%                 1.000000         1.000000
# max                 1.000000         1.000000
#
#        tech_support_No internet service  tech_support_Yes  streaming_tv_No  \
# count                       3937.000000       3937.000000      3937.000000
# mean                           0.220218          0.289307         0.393447
# std                            0.414447          0.453498         0.488577
# min                            0.000000          0.000000         0.000000
# 25%                            0.000000          0.000000         0.000000
# 50%                            0.000000          0.000000         0.000000
# 75%                            0.000000          1.000000         1.000000
# max                            1.000000          1.000000         1.000000
#
#        streaming_tv_No internet service  streaming_tv_Yes  \
# count                       3937.000000       3937.000000
# mean                           0.220218          0.386335
# std                            0.414447          0.486971
# min                            0.000000          0.000000
# 25%                            0.000000          0.000000
# 50%                            0.000000          0.000000
# 75%                            0.000000          1.000000
# max                            1.000000          1.000000
#
#        streaming_movies_No  streaming_movies_No internet service  \
# count          3937.000000                           3937.000000
# mean              0.388367                              0.220218
# std               0.487441                              0.414447
# min               0.000000                              0.000000
# 25%               0.000000                              0.000000
# 50%               0.000000                              0.000000
# 75%               1.000000                              0.000000
# max               1.000000                              1.000000
#
#        streaming_movies_Yes  paperless_billing_No  paperless_billing_Yes  \
# count           3937.000000           3937.000000            3937.000000
# mean               0.391415              0.409703               0.590297
# std                0.488129              0.491841               0.491841
# min                0.000000              0.000000               0.000000
# 25%                0.000000              0.000000               0.000000
# 50%                0.000000              0.000000               1.000000
# 75%                1.000000              1.000000               1.000000
# max                1.000000              1.000000               1.000000
#
#        contract_type_Month-to-month  contract_type_One year  \
# count                   3937.000000             3937.000000
# mean                       0.549911                0.207010
# std                        0.497566                0.405215
# min                        0.000000                0.000000
# 25%                        0.000000                0.000000
# 50%                        1.000000                0.000000
# 75%                        1.000000                0.000000
# max                        1.000000                1.000000
#
#        contract_type_Two year  internet_service_type_DSL  \
# count             3937.000000                3937.000000
# mean                 0.243078                   0.342393
# std                  0.428997                   0.474570
# min                  0.000000                   0.000000
# 25%                  0.000000                   0.000000
# 50%                  0.000000                   0.000000
# 75%                  0.000000                   1.000000
# max                  1.000000                   1.000000
#
#        internet_service_type_Fiber optic  internet_service_type_None  \
# count                        3937.000000                 3937.000000
# mean                            0.437389                    0.220218
# std                             0.496127                    0.414447
# min                             0.000000                    0.000000
# 25%                             0.000000                    0.000000
# 50%                             0.000000                    0.000000
# 75%                             1.000000                    0.000000
# max                             1.000000                    1.000000
#
#        payment_type_Bank transfer (automatic)  \
# count                             3937.000000
# mean                                 0.218948
# std                                  0.413586
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                  1.000000
#
#        payment_type_Credit card (automatic)  payment_type_Electronic check  \
# count                           3937.000000                    3937.000000
# mean                               0.227330                       0.327407
# std                                0.419161                       0.469327
# min                                0.000000                       0.000000
# 25%                                0.000000                       0.000000
# 50%                                0.000000                       0.000000
# 75%                                0.000000                       1.000000
# max                                1.000000                       1.000000
#
#        payment_type_Mailed check
# count                3937.000000
# mean                    0.226314
# std                     0.418498
# min                     0.000000
# 25%                     0.000000
# 50%                     0.000000
# 75%                     0.000000
# max                     1.000000

# %% [markdown]
# # Explore:

# %% [markdown]
# ## How often does churn occur?

# %%
e.get_churn_mean_bar(train)

# %% [markdown]
#  * **It appears that about 26.6% of Telco customers churn.**

# %% [markdown]
# ## Does monthly charges affect churn?

# %%
# Obtain boxplot displaying mean of monthly charges
e.get_monthly_charges(train)

# %% [markdown]
# * **The mean monthly charges of customers who churn is different than the mean monthly charges of customers who do not churn.**

# %% [markdown]
# **I will now conduct a T-test to test for a significant difference between the mean of monthly charges of customers who churn and the mean oc monthly charges of customers who do not churn.**
#
# * The confidence interval is 95%
# * Alpha is set to 0.05
#
# $H_0$: Mean tenure of Telco customers who churn == mean tenure of Telco customers who do not churn.
#
# $H_a$: Tean tenure of Telco customers who churn != mean tenure of Telco customers who do not churn.

# %%
# Stats T-Test result
e.get_ttest_monthly_charges(train)
# Out:
#  t-stat:14.0896
#  p-value:0.0

# %% [markdown]
# **The p-value is less than the alpha. Therefore we have evidence to support that there is a significant difference  between the mean monthly charges of customers who churn vs the mean monthly charges of customers who not churn. Based on this statistical finding I believe that monthly charges is a driver of customer churn.
# Adding an encoded version of this feature to the model will likely increase the model's accuracy.**

# %% [markdown]
# ## Does having Senior Citizen status affect churn?

# %%
# Obtain bar graph for senior Citizen count
e.get_bar_senior(train)

# %% [markdown]
# * **We can see that the count of senior citizens who churn is closer to the total population of senior citizens than the count of non senior citizens population.**

# %% [markdown]
# **I will now conduct a chi-square test to determine if there is an association between senior citizen status and churn.**
#
# * The confidence interval is 95%
# * Alpha is set to 0.05
#
# $H_0$: There is **no** relationship between a customers with senior status and churn.
#
# $H_a$: There is a relationship between a customers senior status and churn.

# %%
# Obtain chi-square test
e.get_chi2_senior(train)
# Out:
#  Chi-Square99.7192
#  p-value:0.0

# %% [markdown]
# **The p-value is less thant the alpha. Therefore, we have evidence to support that a Telcos customer senior citizen status has an association with churn. I believe that senior citizen status is a driver of churn. Adding an encoded version of this feature to the model will likely increase the mode's accuracy.**

# %% [markdown]
# ## Does tenure affect churn?

# %%
# Obtain boxplot on tenure vs churn
e.get_boxplot_tenure(train)

# %% [markdown]
# * **We can see that there is a difference in the tenure mean of customers who churn and the tenure mean of customers who do not churn.**

# %% [markdown]
# **I will now conduct a T-test to determine if there is a significant difference in the tenure means of customers who churn and those who do not churn.**
#
# * The confidence interval is 95%
# * Alpha is set to 0.05
#
# $H_0$: Mean tenure of Telco customers who churn == mean tenure of Telco customers who do not churn.
#
# $H_a$: Tean tenure of Telco customers who churn != mean tenure of Telco customers who do not churn.

# %%
# obtsin T-test for tenure vs churn
e.get_ttest_tenure(train)
# Out:
# False
#  t-stat:-25.77
#  p-value:0.0

# %% [markdown]
# **The p-value is less than alpha. Therefore we have evidence to support that there is a significant difference  between the mean tenure of customers who churn vs the mean tenure of customers who not churn. Based on this statistical finding I believe that tenure is a driver of customer churn.
# Adding an encoded version of this feature to the model will likely increase the model's accuracy.**

# %% [markdown]
# ## Does contract type affect churn?

# %%
# Obtain plot for contract type vs churn
e.get_plot_contract(train)

# %% [markdown]
# * **There seems that customers with Two-year contracts churn less than customers with month-to-month contract.**

# %% [markdown]
# **I will now conduct a chi-square test to determine if there is an association between contract type and churn.**
#
# * The confidence interval is 95%
# * Alpha is set to 0.05
#
# $H_0$: There is **no** relationship between contract type and churn.
#
# $H_a$: There is a relationship between contract type and churn.

# %%
# Obtain chi-square on Contract type
e.get_chi2_contract(train)
# Out:
#  Chi-Square:664.6572
#  p-value:0.0

# %% [markdown]
# **The p-value is less than alpha. Therefore, we have evidence to support that tenure has an association with churn. I believe that tenure is a driver of churn. Adding an encoded version of this feature to the model will likely increase the mode's accuracy.**

# %% [markdown]
# ## Does gender affect churn?

# %%
# Obtain plot for gender vs churn
e.get_plot_gender(train)

# %% [markdown]
# * **There appears to be no relationship between gender and churn.**

# %% [markdown]
# **I will now conduct a chi-square test to determine if there is an association between gender and churn.**
#
# * The confidence interval is 95%
# * Alpha is set to 0.05
#
# $H_0$: There is **no** relationship between gender and churn.
#
# $H_a$: There is a relationship between gender and churn.

# %%
# Run chi-square test
e.get_chi2_gender(train)
# Out:
#  Chi-Square:0.0
#  p-value:1.0

# %% [markdown]
# **The p-value is greater than alpha. Therefore, we have no evidence to support that gender has an association with churn. I believe that gender is not a driver of churn. Adding an encoded version of this feature to the model will likely decrease the mode's accuracy.**

# %% [markdown]
# ## Does having a partner affect churn?

# %%
# Obtain plot for partner vs churn
e.get_plot_partner(train)

# %% [markdown]
# * **There appear to be some association between partner and churn**

# %% [markdown]
# **I will now conduct a chi-square test to determine if there is an association between partner and churn.**
#
# * The confidence interval is 95%
# * Alpha is set to 0.05
#
# $H_0$: There is **no** relationship between partner and churn.
#
# $H_a$: There is a relationship between partner and churn.

# %%
# Run chi-square test on partner vs churn
e.get_chi2_partner(train)
# Out:
#  Chi-Square:80.0893
#  p-value:0.0

# %% [markdown]
# **The p-value is less than alpha. Therefore, we have evidence to support that partner has an association with churn. I believe that partner is a driver of churn. Adding an encoded version of this feature to the model will likely increase the mode's accuracy.**

# %% [markdown]
# # Exploration Summary

# %% [markdown]
# * Monthly Charges is a driver of churn
# * Senior Citizen status is a driver of churn
# * Tenure is a driver of churn
# * Contract type is a driver of churn
# * Partner is a driver of churn
# * Gender is not a driver of churn

# %% [markdown]
# # Features that will be included in my model

# %% [markdown]
# * **Monthly charges**  has a significant statistical relationship to churn
# * **Senior Citizen**  has a significant statistical relationship to churn
# * **Tenure**  has a significant statistical relationship to churn
# * **Contract type** has a significan statistical relationship to churn
# * **Partner**  has a significant statistical relationship to churn

# %% [markdown]
# # Features that will be not included in my model

# %% [markdown]
# * **Gender** did not have a statistical significant relationship to churn.
# * **Other features** have unknow significance to churn at the moment
#     * given more time to I would determined significance to churn and might include on model.

# %% [markdown]
# # Modeling:

# %% [markdown]
# * Accuracy is the metric use in the models.
#     * Accuracy helps gauge the percentage correct predictions.
# * Churn customers makeup 26.5% of the data
# * by guessing non-churn for every customer one could achieve an accuracy of 73.5%
# * 73.5% will be the baseline accuracy I use for this project
#
# !!!* I will be evaluating models developed using four different model types and various hyperparameter configurations
#
# * Models will be evaluated on train and validate data
#
# * The model that performs the best will then be evaluated on test data

# %%
# prep data for modeling
x_train,y_train,x_validate,y_validate, x_test, y_test = m.model_prep(train,validate,test)

# %% [markdown]
# ## Decision Tree

# %%
# Get Decision Tree results
m.get_tree_model(x_train,y_train,x_validate,y_validate)
# Out:
# Accuracy of Decision Tree on train data is 0.7899415798831597 about 78.99%
# Accuracy of Decision Tree on validate data is 0.7766587677725119about 77.67%
# Difference between train and validate accuracy: 0.0133

# %% [markdown]
# **The accuracy of the Decision Tree model is above the baseline in both train and validate.**

# %% [markdown]
# ## Random Forest

# %%
# Get Random Forest results
m.get_random_forest_model(x_train,y_train,x_validate,y_validate)
# Out:
# Accuracy of Random Forest on train data is 0.8214376428752858 about 82.14%
# Accuracy of Random Forest on validate data is 0.7843601895734598 about 78.44%
# Difference between train and validate accuracy: 0.0371

# %% [markdown]
# **The accuracy of the Decision Tree model is above the baseline in both train and validate.**

# %% [markdown]
# ## KNN

# %%
# Get KNN model results
m.get_knn_model(x_train,y_train,x_validate,y_validate)
# Out:
# Accuracy of KNN on train data is 0.8016256032512065 about 80.16%
# Accuracy of KNN on validate data is 0.7802132701421801 about 78.02%
# Difference between train and validate accuracy: 0.0214

# %% [markdown]
# **The accuracy of the Decision Tree model is above the baseline in both train and validate.**

# %% [markdown]
# ## Logistic Regression

# %%
# Get Logic Regression model results
m.get_logit_model(x_train,y_train,x_validate,y_validate)
# Out:
# Accuracy of Logistic Regression on train data is 0.7896875793751588 about 78.97%
# Accuracy of Logistic Regression on validate data is 0.7784360189573459 about 77.84%
# Difference between train and validate accuracy: 0.0113

# %% [markdown]
# **The accuracy of the Decision Tree model is above the baseline in both train and validate.**

# %% [markdown]
# # Comparing Models

# %% [markdown]
# * All Models performed above the baseline in both train and validate data
# * Since all models performed well I will select the Model with the least accuracy diffirence between train and validate
# * I will select the Logistic Regression as the final model.

# %% [markdown]
# # Logistic regression on Test data

# %%
# Get Logic Regression model results on test data
m.get_logit_model(x_train,y_train,x_test,y_test, True)
# Out:
# Accuracy of Logistic Regression on train data is 0.7896875793751588 about 78.97%
# Accuracy of Logistic Regression on test data is 0.8052594171997157 about 80.53%
# Difference between validate and test accuracy: -0.0156

# %% [markdown]
# ## Modeling Summary

# %% [markdown]
# * Logistic regression performed above the baseline on test data by about 7%.

# %% [markdown]
# # Conclusion

# %% [markdown]
# ## Next Steps

# %% [markdown]
# ## Modeling

# %% [markdown]
# ## Recommendations

# %% [markdown]
# ## Next Steps
